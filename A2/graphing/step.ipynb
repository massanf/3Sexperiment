# %%
run graphing.ipynb

# %%
plt.figure(figsize=(8, 4), dpi=80)
graph_time("biseki_response_deriv.txt")
plt.xlim(-0.01,0.1)

plt.savefig("figures/ステップ/微分.png")

# %%
plt.figure(figsize=(8, 4), dpi=80)
graph_time("biseki_response_integ.txt")
plt.xlim(-0.00000001,0.0000001)

plt.savefig("figures/ステップ/積分.png")

# %%
plt.figure(figsize=(8, 4), dpi=80)
graph_time("biseki_response_inverse.txt")
plt.xlim(-0.0001,0.001)

plt.savefig("figures/ステップ/反転.png")

# %%
#test
plt.figure(figsize=(8, 4), dpi=80)
graph_time("biseki_response_deriv.txt")
graph_time("biseki_response_inverse.txt")
plt.xlim(-0.0001,0.001)

plt.savefig("figures/ステップ/微分.png")
