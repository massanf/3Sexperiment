# %%
run graphing.ipynb

# %%
plt.figure(figsize=(8, 4), dpi=80)
graph_time("biseki_response_deriv.txt",2,name="V_out")
graph_time("biseki_response_deriv.txt",1,linestyle_="dotted",name="V_in")
plt.xlim(-0.01,0.1)

plt.savefig("figures/ステップ/微分.png")

# %%
plt.figure(figsize=(8, 4), dpi=80)
graph_time("biseki_response_integ.txt",2,name="V_out")
graph_time("biseki_response_integ.txt",1,linestyle_="dotted",name="V_in")
plt.xlim(-0.000000025,0.0000001)

plt.savefig("figures/ステップ/積分.png")

# %%
plt.figure(figsize=(8, 4), dpi=80)
graph_time("biseki_response_inverse.txt",2,name="V_out")
graph_time("biseki_response_inverse.txt",1,linestyle_="dotted",name="V_in")
plt.xlim(-0.0001,0.001)

plt.savefig("figures/ステップ/反転.png")
