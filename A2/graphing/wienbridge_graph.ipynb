# %% [markdown]
# # ウィーンブリッジ

# %%
run graphing.ipynb

# %%
plt.figure(figsize=(8, 4), dpi=80)
plot_gain("wienbridge_oscillation_k=0.501.txt",xlim=[0,10000])

plt.savefig("figures/ウィーンブリッジ/k=0.501.png")
# Out:
# Graphing: wienbridge_oscillation_k=0.501.txt

# %%
plt.figure(figsize=(8, 4), dpi=80)
plot_gain("wienbridge_oscillationafter_k=0.8.txt",xlim=[0,10000])
#764
for i in range (0, 14):
    drawline(plt,"x",764*i,printbool=True,linestyle_="dotted")
    
k=0.8
C=16.7*10**-9
R=10000

def H(s):
    return k*s*C*R/((s*C*R)**2+3*s*C*R + 1)

Y = []
X = []
for f in range (0, 100):
    #Y.append(20*np.log10(H(1j*2*math.pi*f*100)))
    X.append(f*100)
    
plt.savefig("figures/ウィーンブリッジ/k=0.8.png")
# Out:
# Graphing: wienbridge_oscillationafter_k=0.8.txt
# Vertical Line at: x=0
# Vertical Line at: x=764
# Vertical Line at: x=1528
# Vertical Line at: x=2292
# Vertical Line at: x=3056
# Vertical Line at: x=3820
# Vertical Line at: x=4584
# Vertical Line at: x=5348
# Vertical Line at: x=6112
# Vertical Line at: x=6876
# Vertical Line at: x=7640
# Vertical Line at: x=8404
# Vertical Line at: x=9168
# Vertical Line at: x=9932

# %%
plt.figure(figsize=(8, 4), dpi=80)
plot_gain("wienbridge_oscillationbefore_k=0.3.txt",xlim=[0,10000])

plt.savefig("figures/ウィーンブリッジ/k=0.3.png")
# Out:
# Graphing: wienbridge_oscillationbefore_k=0.3.txt

# %%
fig, (ax1,ax2) = plt.subplots(nrows=2, ncols=1, figsize = (8,8), tight_layout = True)
plt.figure(figsize=(8, 4), dpi=80)
plot_gain_k("openloop_spectrum.txt",xlim=[0,1000000])

drawline(ax1,"y",0)
drawline(ax2,"y",0)
drawline(ax2,"x",952,printbool=True)

plt.savefig("figures/ウィーンブリッジ/openloop.png")
# Out:
# Graphing: openloop_spectrum.txt
# 1 Step Information: K=110m  (Run: 2/10)
#
# 2 Step Information: K=210m  (Run: 3/10)
#
# 3 Step Information: K=310m  (Run: 4/10)
#
# 4 Step Information: K=410m  (Run: 5/10)
#
# 5 Step Information: K=510m  (Run: 6/10)
#
# 6 Step Information: K=610m  (Run: 7/10)
#
# 7 Step Information: K=710m  (Run: 8/10)
#
# 8 Step Information: K=810m  (Run: 9/10)
#
# 9 Step Information: K=910m  (Run: 10/10)
#
# Vertical Line at: x=952
